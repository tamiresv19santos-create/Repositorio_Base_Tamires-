# %% [markdown]
# ### 📌 Desafio: Sistema de Gerenciamento de Notas Escolares
#
# Nível: Intermediário
#
# Habilidades Exercitadas:
#
# ✔️ Loops for e/ou While
#
#
# ✔️ Manipulação de listas
#
#
# ✔️ Operações matemáticas básicas
#
#
# ✔️ Validação de entrada

# %% [markdown]
# 📋 Contexto
# Você foi contratado para desenvolver um sistema de gerenciamento de notas para a escola Python Academy. O programa deve:
#
# - Coletar notas de alunos
#
# - Calcular estatísticas
#
# - Identificar situações especiais

# %% [markdown]
# ### 🎯 Requisitos
#
# ### 1️⃣ Entrada de Dados (Usando for)
# O programa deve perguntar quantos alunos a turma tem.
#
# Para cada aluno, coletar:
#
# 📛 Nome (texto)
#
#
# 📚 Notas (3 notas, de 0 a 10)
#
#
# 🏷️ Turma (A, B ou C)

# %% [markdown]
# ### 2️⃣ Processamento (Listas + Loops)
#
# Armazenar todos os dados em listas separadas:

# %%
nomes = []
notas = []  # Lista de listas (cada aluno tem 3 notas)
turmas = []

quantidade_alunos = int(input("quantos alunos temos ao todo em nossa escola??"))

for i in range(quantidade_alunos):
    print(f"\naluno{i+1}:")
    nome = input("nome do aluno:")
    nota1 = float(input("nota1 (0 a 10):)"))
    nota2= float(input("nota2 (0 a 10):)"))
    nota3  = float(input("nota3 (0 a 10):)"))
    turma = input("turma (A,B, ou C)")
    nome.append(nome)
    notas.append(nota1)
    notas.append(nota2)
    notas.append(nota3)
    turmas.append(turmas)
    print("\n---RESULTADO ---")
    for i in range (quantidade_alunos):
        media=notas[i]/ 3
# Out:
#   Cell In[1], line 20
#     print(f"{nome}[i]"(turmas}{i}: mesia= }{media:>2f}))
#                              ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '('

# %% [markdown]
# Calcular para cada aluno:
#
# 📊 Média (soma das 3 notas / 3)
#
# 🔍 Status:
#
# - "Aprovado" se média ≥ 7
#
# - "Recuperação" se 5 ≤ média < 7
#
# - "Reprovado" se média < 5

# %% [markdown]
# ### 3️⃣ Saída Esperada
#
# No final, exibir:
#
# 📜 Relatório Individual (para cada aluno):
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 💡 Exemplo de Funcionamento

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 🔍 Dicas para Implementação
#
# Use for i in range(num_alunos) para coletar dados.

# %% [markdown]
# Para calcular médias:

# %%
media = sum(notas_aluno) / 3

# %% [markdown]
# Utilize listas aninhadas para notas:

# %%
notas = [[6, 7, 5], [8, 9, 10]]  # Exemplo

# %% [markdown]
# Para estatísticas:
#
# Média geral: sum(todas_medias) / num_alunos
#
# Melhor aluno: max(medias) + índice correspondente.

# %% [markdown]
# ### ✨ Desafio Extra (Opcional)
#
# Adicione um sistema de busca por nome para consultar um aluno específico.
#
# Salve os dados em um arquivo .txt ao final.
#
# Objetivo: Praticar estruturas de repetição e listas em um contexto realista! 💻🎓
#
# Quer uma solução de referência? Comente! 😊
